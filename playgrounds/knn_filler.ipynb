# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
import scipy.stats as stats
from main import get_data

data, labels, continuous, discrete, dummy, categorical = get_data()

# %%
from sklearn.base import BaseEstimator, TransformerMixin
import pandas as pd
import numpy as np


def get_nn_value(x, data, y, k, dist_fn):
    distances = np.apply_along_axis(lambda x2: dist_fn(x2, x), 1, data)
    print(distances)
    ind = np.argpartition(distances, k)[:k]
    print("ind: ", ind)
    print(np.median(y[ind]))
    return np.median(y[ind])

def dist_fn1(a, x):
    dist = np.nan_to_num(x - a)
    return np.sqrt(np.sum(np.power(dist, 2)))

# %%
class KnnFiller(BaseEstimator, TransformerMixin):
    def __init__(self, k, dist_fn):
        self.k = k
        self.dist_fn = dist_fn
    
    def fit(self, X, y, **fit_params):
        self.ids = X.index
        self.data = X.values
        return self

    def transform(self, X):
        cols = X.columns[X.isna().any()].tolist()
        for col in cols:
            j = X.columns.get_loc(col)
            rest = self.data[~np.isnan(self.data[:,j]),:]
            y = rest[:,j]
            rest = np.delete(rest, j, 1)
            for i, row in X.iterrows():
                if pd.isnull(row[col]):
                    if i in self.ids:
                        filtered = np.delete(rest, self.ids.get_loc(i), 0)
                    else:
                        filtered = rest
                    X[col][i] = get_nn_value(row.drop(col).values, filtered, y, self.k, self.dist_fn)


        return X

# %%
df = data.drop('Product_Info_2', axis = 1).iloc[:20, :7].set_index('Id')

# %%
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Product_Info_1</th>
#       <th>Product_Info_3</th>
#       <th>Product_Info_4</th>
#       <th>Product_Info_5</th>
#       <th>Product_Info_6</th>
#       <th>Product_Info_7</th>
#     </tr>
#     <tr>
#       <th>Id</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>33308</th>
#       <td>NaN</td>
#       <td>29</td>
#       <td>0.230769</td>
#       <td>2</td>
#       <td>3</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>74812</th>
#       <td>1.0</td>
#       <td>26</td>
#       <td>0.076923</td>
#       <td>2</td>
#       <td>3</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>23707</th>
#       <td>1.0</td>
#       <td>26</td>
#       <td>NaN</td>
#       <td>2</td>
#       <td>3</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>668</th>
#       <td>1.0</td>
#       <td>26</td>
#       <td>NaN</td>
#       <td>2</td>
#       <td>3</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>65826</th>
#       <td>NaN</td>
#       <td>26</td>
#       <td>0.230769</td>
#       <td>2</td>
#       <td>3</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>21487</th>
#       <td>1.0</td>
#       <td>26</td>
#       <td>0.230769</td>
#       <td>2</td>
#       <td>3</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>66051</th>
#       <td>1.0</td>
#       <td>26</td>
#       <td>0.025641</td>
#       <td>2</td>
#       <td>3</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>51785</th>
#       <td>1.0</td>
#       <td>26</td>
#       <td>0.076923</td>
#       <td>2</td>
#       <td>3</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>73035</th>
#       <td>1.0</td>
#       <td>26</td>
#       <td>0.333333</td>
#       <td>2</td>
#       <td>3</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>48958</th>
#       <td>1.0</td>
#       <td>26</td>
#       <td>0.487179</td>
#       <td>2</td>
#       <td>3</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4014</th>
#       <td>1.0</td>
#       <td>26</td>
#       <td>0.076923</td>
#       <td>2</td>
#       <td>3</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>48230</th>
#       <td>1.0</td>
#       <td>10</td>
#       <td>0.743590</td>
#       <td>2</td>
#       <td>3</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>47051</th>
#       <td>1.0</td>
#       <td>26</td>
#       <td>0.179487</td>
#       <td>2</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>34590</th>
#       <td>1.0</td>
#       <td>10</td>
#       <td>0.230769</td>
#       <td>2</td>
#       <td>3</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>56952</th>
#       <td>1.0</td>
#       <td>26</td>
#       <td>1.000000</td>
#       <td>2</td>
#       <td>3</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>890</th>
#       <td>1.0</td>
#       <td>26</td>
#       <td>0.230769</td>
#       <td>2</td>
#       <td>3</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>16027</th>
#       <td>1.0</td>
#       <td>26</td>
#       <td>0.230769</td>
#       <td>2</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4101</th>
#       <td>1.0</td>
#       <td>29</td>
#       <td>0.589744</td>
#       <td>2</td>
#       <td>3</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>22367</th>
#       <td>1.0</td>
#       <td>26</td>
#       <td>0.487179</td>
#       <td>2</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>23122</th>
#       <td>1.0</td>
#       <td>26</td>
#       <td>0.025641</td>
#       <td>2</td>
#       <td>3</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
kf = KnnFiller(5, dist_fn1)
kf.fit(df, df.iloc[:,5])

# %%
to_drop = data.columns[data.isnull().sum() > 20000]
dropped = data.drop(to_drop, axis=1)

# %%
# X = pd.DataFrame({'A': [0, 1, 4, 5, 0 ,1, 0], 'B': [0, 3, np.NaN, np.NaN, 1, 2, np.NaN], 'C': [0, 2, 3, np.NaN, 1, 3,np.NaN]})
X = pd.DataFrame({
    'A': [0, 1, 4, 5, 0 ,1, 0],
    'B': [0, 3, np.NaN, np.NaN, 1, 2, 0],
    'C': [0, 2, 3, 0, 1, 3, 0],
    'B_nan': [False, False, True, True, False, False, True],
    'C_nan': [True, True, True, False, False, False, True]
})
with_nan = X[X[['B']].isnull().any(axis=1) |  (X['B'] < 1)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e2bad4ae6591> in <module>()
#       1 # X = pd.DataFrame({'A': [0, 1, 4, 5, 0 ,1, 0], 'B': [0, 3, np.NaN, np.NaN, 1, 2, np.NaN], 'C': [0, 2, 3, np.NaN, 1, 3,np.NaN]})
# ----> 2 X = pd.DataFrame({
#       3     'A': [0, 1, 4, 5, 0 ,1, 0],
#       4     'B': [0, 3, np.NaN, np.NaN, 1, 2, 0],
#       5     'C': [0, 2, 3, 0, 1, 3, 0],
#
# NameError: name 'pd' is not defined

# %%
# X.loc[X['B'].isnull(), 'B'] = with_nan['A'].map(a['Ht'])
X

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.cluster import KMeans
import pandas as pd
import numpy as np


class HotDeckImputer(BaseEstimator, TransformerMixin):
    def __init__(self, columns, k=8):
        self.columns = columns
        self.k = k

    def fit(self, X, y=None, **fit_params):
        self.clusterer = KMeans(n_clusters=self.k)
        without_na = X.dropna(axis=0)

        # fit KMeans to other columns
        without_target_cols = without_na.drop(self.columns, axis=1)
        self.clusterer.fit(without_target_cols)

        just_target_cols = without_na[self.columns]
        # get mean of specified attributes per each cluster
        just_target_cols['cluster'] = self.clusterer.predict(without_target_cols)
        self.values_per_cluster = just_target_cols.groupby('cluster').apply(np.mean)
        return self

    def transform(self, X):
        rows_with_nan = X[X[self.columns].isnull().any(axis=1)]
        without_target_cols = rows_with_nan.drop(self.columns, axis=1)
        rows_with_nan['cluster'] = self.clusterer.predict(without_target_cols)
        for col in self.columns:
            X.loc[X[col].isnull(), col] = rows_with_nan['cluster'].map(self.values_per_cluster[col])
        return X
    
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.cluster import KMeans
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline


class HotDeckColImputer(BaseEstimator, TransformerMixin):
    """
    Uses colname_nan to indicate which rows were nan
    """
    def __init__(self, column, k=8):
        self.column = column
        self.k = k

    def fit(self, X, y=None, **fit_params):
        self.clusterer = KMeans(n_clusters=self.k)

        without_na = X[~X[self.column + '_nan']]
        with_na = X[X[self.column + '_nan']]

        # fit KMeans to other columns
        without_target_col = without_na.drop([self.column, self.column + '_nan'], axis=1)
        self.clusterer.fit(without_target_col)

        just_target_col = without_na[[self.column]]
        # get mean of specified attributes per each cluster
        just_target_col['cluster'] = self.clusterer.predict(without_target_col)
        self.values_per_cluster = just_target_col.groupby('cluster').apply(np.mean)[self.column]
        return self

    def transform(self, X):
        with_na = X[X[self.column + '_nan']]
        without_target_col = with_na.drop([self.column, self.column + '_nan'], axis=1)
        with_na['cluster'] = self.clusterer.predict(without_target_col)
        X.loc[X[self.column + '_nan'], self.column] = with_na['cluster'].map(self.values_per_cluster)
        return X

class HotDeckFullImputer(BaseEstimator, TransformerMixin):
    def __init__(self, col_k_pairs, default_k=8):
        """
        col_k_pairs: list of tuples (column name, k or none)
        """
        imputers = [(col + '_imputer', HotDeckColImputer(column=col, k=(k or default_k))) for col, k in col_k_pairs]
        self.pipe = Pipeline(imputers)

    def fit(self, X, y=None, **fit_params):
        return self.pipe.fit(X, y)

    def transform(self, X):
        return self.pipe.transform(X)

# %%
hot_deck = HotDeckFullImputer([('B',1), ('C', 2)])
hot_deck.fit(X)
# Out:
# /home/johnny/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/johnny/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Pipeline(memory=None,
#      steps=[('B_imputer', HotDeckColImputer(column='B', k=1)), ('C_imputer', HotDeckColImputer(column='C', k=2))])

# %%
hot_deck.transform(X)
# Out:
# /home/johnny/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>B_nan</th>
#       <th>C</th>
#       <th>C_nan</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>0.0</td>
#       <td>False</td>
#       <td>2.0</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>3.0</td>
#       <td>False</td>
#       <td>2.0</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4</td>
#       <td>1.5</td>
#       <td>True</td>
#       <td>0.0</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5</td>
#       <td>1.5</td>
#       <td>True</td>
#       <td>0.0</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0</td>
#       <td>1.0</td>
#       <td>False</td>
#       <td>1.0</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1</td>
#       <td>2.0</td>
#       <td>False</td>
#       <td>3.0</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0</td>
#       <td>1.5</td>
#       <td>True</td>
#       <td>2.0</td>
#       <td>True</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import Lasso

from transformers.one_hot_encoder import CustomOneHotEncoder

onehot = CustomOneHotEncoder(columns=categorical)
df = onehot.fit_transform(data).fillna(0).drop('Response', axis=1)
selector = SelectFromModel(Lasso())

# %%
selector.fit(df, labels)
# Out:
# SelectFromModel(estimator=Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False),
#         norm_order=1, prefit=False, threshold=None)

# %%
selector.transform(df).shape
# Out:
# (10000, 4)
